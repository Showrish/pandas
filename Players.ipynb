# %% [markdown]
# <a href="https://colab.research.google.com/github/Showrish/pandas/blob/master/Players.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as mp
import numpy as np
players=np.array(['Rohit','Kohli','Hardik','SriRam','Dhoni'])
runs=np.array([45,1,5,0,95])
oruns=np.array([98,56,12,0,43])
mp.plot(players,runs,'o',ls=':',mfc='r',mec='g',label='T20')
mp.plot(players,oruns,'o',mfc='b',ls='-',label='ODI')
mp.legend()
mp.xlabel('PLAYERS')
mp.ylabel('RUNS')
mp.show()
